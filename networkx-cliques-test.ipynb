# %%
import networkx as nx

# %%
g=nx.octahedral_graph()

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(g)

# %%
kg=nx.make_max_clique_graph(g)

# %%
kg.nodes(), g.nodes()
# Out:
# (NodeView((0, 1, 2, 3, 4, 5, 6, 7)), NodeView((0, 1, 2, 3, 4, 5)))

# %%
nx.draw(kg)

# %%
K=nx.make_max_clique_graph

# %%
k2g=K(kg)

# %%
nx.draw(k2g)

# %%
k2g.order()
# Out:
# 16

# %%
nx.enumerate_all_cliques(g)
# Out:
# <generator object enumerate_all_cliques at 0xa8835930>

# %%
list(_)
# Out:
# [[0],
#  [1],
#  [2],
#  [3],
#  [4],
#  [5],
#  [0, 1],
#  [0, 2],
#  [0, 3],
#  [0, 4],
#  [1, 2],
#  [1, 3],
#  [1, 5],
#  [2, 4],
#  [2, 5],
#  [3, 4],
#  [3, 5],
#  [4, 5],
#  [0, 1, 2],
#  [0, 1, 3],
#  [0, 2, 4],
#  [0, 3, 4],
#  [1, 2, 5],
#  [1, 3, 5],
#  [2, 4, 5],
#  [3, 4, 5]]

# %%
nx.find_cliques(g)
# Out:
# <generator object find_cliques at 0xa88376f0>

# %%
list(_)
# Out:
# [[0, 1, 2],
#  [0, 1, 3],
#  [0, 4, 2],
#  [0, 4, 3],
#  [5, 1, 2],
#  [5, 1, 3],
#  [5, 4, 2],
#  [5, 4, 3]]

# %%
nx.draw_spectral(k2g)

# %%
plt.draw()
plt.show()

# %%
nx.draw_networkx(g, with_labels=True)

# %%
nx.draw_networkx(kg, font_color='w', width=2, with_labels=True, node_color='b')

# %%
g[0]
# Out:
# AtlasView({1: {}, 2: {}, 3: {}, 4: {}})

# %%
[v for v in g]
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
g.graph, kg.graph
# Out:
# ({'name': 'Platonic Octahedral Graph'}, {})

# %%
g.edges(), g.edges(0)
# Out:
# (EdgeView([(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 5), (2, 4), (2, 5), (3, 4), (3, 5), (4, 5)]),
#  EdgeDataView([(0, 1), (0, 2), (0, 3), (0, 4)]))

# %%
[e for e in g.edges(1)]
# Out:
# [(1, 0), (1, 2), (1, 3), (1, 5)]

# %%
[d for d in g.adjacency()]
# Out:
# [(0, {1: {}, 2: {}, 3: {}, 4: {}}),
#  (1, {0: {}, 2: {}, 3: {}, 5: {}}),
#  (2, {0: {}, 1: {}, 4: {}, 5: {}}),
#  (3, {0: {}, 1: {}, 4: {}, 5: {}}),
#  (4, {0: {}, 2: {}, 3: {}, 5: {}}),
#  (5, {1: {}, 2: {}, 3: {}, 4: {}})]

# %%
g.degree(1), g.degree[2], g.degree
# Out:
# (4, 4, DegreeView({0: 4, 1: 4, 2: 4, 3: 4, 4: 4, 5: 4}))

# %%
h=g.subgraph([0,1,2,5])

# %%
D=nx.draw_networkx

# %%
D(h)

# %%
it=nx.find_cliques(g)

# %%
next(it)
# Out:
# [0, 1, 2]

# %%
next(it)
# Out:
# [0, 1, 3]

# %%
K??
